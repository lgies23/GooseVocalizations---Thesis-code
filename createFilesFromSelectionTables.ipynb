# %% [markdown]
# This script reads in the original "tracks" (already homogenzied to 16 bit, 41100 Hz, mono - done using the *fix_wavs* method of *warbleR* package in R) and corresponding selection tables (Raven).
#
# Clipped tracks are discarded and the remaining files noise reduced. Clips are then saved as wav files from valid selections (i.e. call type label does not include "unusable", etc.).
#
# File naming convention is: *\<Track ID\>\_\<Clip ID\>\_\<Goose ID\>\_\<call type\>.wav*

# %%
import glob
from pathlib import Path
import pandas as pd
import numpy as np

import librosa
import noisereduce as nr
from scipy.io import wavfile
from maad.sound import spectral_snr

import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATAPATH = "/Users/lenagies/Desktop/Master/Thesis/geese/data"
OUTPATH = "/Users/lenagies/Desktop/Master/Thesis/geese/data/clips_from_selections"
MASTERFILE_NAME = "LATEST_greylag_goose_call_masterfile_cleaned.xlsx"

track_paths = glob.glob(DATAPATH+"/tracks/homogenized_sound_files/*.wav")
track_paths += glob.glob(DATAPATH+"/tracks/homogenized_sound_files/*.WAV")
track_paths += glob.glob(DATAPATH+"/tracks/Jonas/homogenized_sound_files/*.WAV")
track_paths += glob.glob(DATAPATH+"/tracks/Jonas/homogenized_sound_files/*.wav")
track_paths += glob.glob(DATAPATH+"/tracks/Lena/homogenized_sound_files/*.WAV")
track_paths += glob.glob(DATAPATH+"/tracks/Lena/homogenized_sound_files/*.wav")
selection_paths = glob.glob(DATAPATH+"/selections/*.txt")
selection_paths += glob.glob(DATAPATH+"/selections/Jonas/*.txt")
selection_paths += glob.glob(DATAPATH+"/selections/Lena/*.txt")

# %% [markdown]
# Keep only filepaths for wavs with existing selection table and discard clipped tracks. These are listed in */Users/lenagies/Desktop/Master/Thesis/geese/data/clipped_files.rtf* which was created with the following sox commands:
#
# ```
# find . | while read LINE
# do
#  sox "$LINE" -n --norm -R gain 0 2>&1 | grep clipped && echo "$LINE"
# done
# ```

# %%
track_paths = [track_path for track_path in track_paths if (track_path.split("/")[-1].split(".")[0]) in '\n'.join(selection_paths)]
print(len(track_paths))
# Out:
# 663

# %%
clipped_files = []
f = open("/Users/lenagies/Desktop/Master/Thesis/geese/data/clipped_files.rtf", "r")
for line in f:
  if line.startswith("sox") and "1 samples" in line:
    f.readline()
  if line.startswith("./"):
    clipped_files.append(line.split("/")[-1].replace("\\\n", ""))

print(len(clipped_files))
# Out:
# 70

# %%
track_paths = [track_path for track_path in track_paths if not (track_path.split("/")[-1].split(".")[0]) in '\n'.join(clipped_files)]
print(len(track_paths))
# Out:
# 632

# %% [markdown]
# Open Masterfile into dataframe and only keep rows for remaining tracks

# %%
master_df = pd.read_excel(Path(DATAPATH, MASTERFILE_NAME))
master_df = master_df[master_df['Track ID'].isin([(track_path.split("/")[-1].split(".")[0]) for track_path in track_paths])]
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8225 entries, 23 to 12782
# Data columns (total 24 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Track ID                                                           8225 non-null   object
#  1   Clip ID                                                            7624 non-null   object
#  2   Bout Call ID * formerly Neckband Nr; but no single entry was made  2 non-null      object
#  3   Goose ID                                                           8225 non-null   object
#  4   upper left                                                         1364 non-null   object
#  5   mid left                                                           1132 non-null   object
#  6   lower left                                                         568 non-null    object
#  7   upper right                                                        1301 non-null   object
#  8   mid right                                                          999 non-null    object
#  9   lower right                                                        509 non-null    object
#  10  Location                                                           8225 non-null   object
#  11  Day                                                                8225 non-null   float64
#  12  Month                                                              8225 non-null   float64
#  13  Year                                                               8225 non-null   float64
#  14  Date                                                               1400 non-null   object
#  15  Time                                                               8217 non-null   object
#  16  Recorder                                                           946 non-null    object
#  17  Microphone                                                         8225 non-null   object
#  18  Call Type                                                          8151 non-null   object
#  19  Comment                                                            1390 non-null   object
#  20  Wav Treatment                                                      372 non-null    object
#  21  Context                                                            251 non-null    object
#  22  Recorder ID                                                        8225 non-null   object
#  23  ...24                                                              0 non-null      float64
# dtypes: float64(4), object(20)
# memory usage: 1.6+ MB

# %% [markdown]
# Create a dataframe from the Raven selection tables with Begin Time, End Time, Call Type and Clip ID. We will ignore information about the goose ID and use that of the Masterfile. Call types will however be taken from the selection tables as unusable calls were marked here and call types double checked.

# %%
selections_df = pd.DataFrame(columns=["Begin Time (s)",	"End Time (s)",	"Call Type", "Clip ID"])

for selection_path in [selection_path for selection_path in selection_paths if selection_path.split("/")[-1].split(".")[0] in '\n'.join(track_paths)]:
    try: 
        lineterminator = '\r' if "Jonas" in selection_path else '\n'
        annotation_columns = ['Clip ID', 'Goose ID'] if "Jonas" in selection_path else ['Clip ID', 'Goose ID', 'Call Type']
        temp_df = pd.read_csv(selection_path, sep='\t', lineterminator=lineterminator)
        temp_df = temp_df[temp_df["View"] == "Spectrogram 1"] if "View" in temp_df.columns else temp_df
        if "Channel" in temp_df.columns:
            temp_df = temp_df[temp_df["Channel"] == 1] if len(temp_df[temp_df["Channel"] == 1]) > 0 else temp_df[temp_df["Channel"] == 2]
        if not "Annotation" in temp_df.columns:
            print(temp_df.columns.str.split("\t"))
        temp_df[annotation_columns] = temp_df['Annotation'].str.split('_', expand=True)
        if "Jonas" in selection_path:    
            temp_df['Call Type'] = np.nan
        temp_df = temp_df.drop(columns=["Low Freq (Hz)", "High Freq (Hz)", "Delta Freq (Hz)", "Avg Power Density (dB FS/Hz)", "Delta Time (s)", "Channel", "View", "Selection", "Annotation", "Goose ID"], errors="ignore")
        selections_df = pd.concat([selections_df, temp_df], ignore_index=True)
    except Exception as e:
        print(e, selection_path)
        continue
        
selections_df.info()
# Out:
# /var/folders/kl/qgqbw3bd42bf_tybhvnz9vxh0000gn/T/ipykernel_39772/251451586.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   selections_df = pd.concat([selections_df, temp_df], ignore_index=True)
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00693.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00650.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00491.txt
# 'utf-8' codec can't decode byte 0xfc in position 222: invalid start byte /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00731.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00484.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00692.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00647.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00653.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00524.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00444.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00478.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00646.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00468.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00509.txt
# 'utf-8' codec can't decode byte 0xdf in position 228: invalid continuation byte /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00521.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00441.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00494.txt
# Columns must be same length as key /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00443.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00481.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00495.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00790.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00791.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00578.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00621.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00436.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00554.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00569.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00555.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00565.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00573.txt
# 'utf-8' codec can't decode byte 0xfc in position 224: invalid start byte /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00549.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00789.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00548.txt
# 'utf-8' codec can't decode byte 0xdf in position 388: invalid continuation byte /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00574.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00498.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00467.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00475.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00717.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00500.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00460.txt
# 'utf-8' codec can't decode byte 0xfc in position 221: invalid start byte /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00660.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00648.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00700.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00728.txt
# Can only use .str accessor with string values! /Users/lenagies/Desktop/Master/Thesis/geese/data/selections/Jonas/GT00517.txt
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7516 entries, 0 to 7515
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Begin Time (s)  7516 non-null   float64
#  1   End Time (s)    7516 non-null   float64
#  2   Call Type       2258 non-null   object
#  3   Clip ID         7515 non-null   object
# dtypes: float64(2), object(2)
# memory usage: 235.0+ KB

# %% [markdown]
# Only keep rows for which selections exist. Only keep new call type annotations, or, if no call type specification exists for the selection, use that of the masterfile.

# %%
master_df = master_df.dropna(subset='Clip ID')
master_df = pd.merge(master_df, selections_df, on="Clip ID", how="inner")
del selections_df, temp_df
master_df['Call Type_y'] = master_df['Call Type_y'].fillna(master_df['Call Type_x']) # if selections did not include call type specification, use that of the masterfile
master_df = master_df.dropna(subset=['Begin Time (s)']).drop(columns=['Call Type_x']).rename(columns={"Call Type_y": "Call Type"})
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7516 entries, 0 to 7515
# Data columns (total 26 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Track ID                                                           7516 non-null   object
#  1   Clip ID                                                            7516 non-null   object
#  2   Bout Call ID * formerly Neckband Nr; but no single entry was made  0 non-null      object
#  3   Goose ID                                                           7516 non-null   object
#  4   upper left                                                         1129 non-null   object
#  5   mid left                                                           924 non-null    object
#  6   lower left                                                         469 non-null    object
#  7   upper right                                                        1079 non-null   object
#  8   mid right                                                          831 non-null    object
#  9   lower right                                                        425 non-null    object
#  10  Location                                                           7516 non-null   object
#  11  Day                                                                7516 non-null   float64
#  12  Month                                                              7516 non-null   float64
#  13  Year                                                               7516 non-null   float64
#  14  Date                                                               1153 non-null   object
#  15  Time                                                               7509 non-null   object
#  16  Recorder                                                           958 non-null    object
#  17  Microphone                                                         7516 non-null   object
#  18  Comment                                                            1188 non-null   object
#  19  Wav Treatment                                                      371 non-null    object
#  20  Context                                                            253 non-null    object
#  21  Recorder ID                                                        7516 non-null   object
#  22  ...24                                                              0 non-null      float64
#  23  Begin Time (s)                                                     7516 non-null   float64
#  24  End Time (s)                                                       7516 non-null   float64
#  25  Call Type                                                          7516 non-null   object
# dtypes: float64(6), object(20)
# memory usage: 1.5+ MB

# %% [markdown]
# Discard all calls that include a call type annotation including "unusable" or "discard" and only keep one word for call type.

# %%
len(master_df[master_df['Call Type'].str.contains("discard|unusable")])
# Out:
# 7

# %%
master_df = master_df[master_df['Call Type'].str.contains("discard|unusable|duplicate") == False]

# %%
len(master_df)
# Out:
# 7508

# %% [markdown]
# Change call type values to contain a single word for the call type, if the original value contains one of our defined call types (and a few differently labeled types that we want to keep to check later).

# %%
master_df.groupby('Call Type')['Clip ID'].count()
# Out:
# Call Type
# Short loud call - contact call?                                              1
# alarm call                                                                  63
# alarm call?                                                                  4
# alarmCall                                                                   35
# answer triumph call?                                                         3
# contact  call                                                                7
# contact call                                                              1630
# contact call (to human observer)                                             1
# contact call?                                                               54
# contact call? (displaced someone but no ceremony)                            2
# contact call? after beeing vigilant                                          4
# departure                                                                   14
# departure (original recruitment)                                             1
# departure call                                                             840
# departure call?                                                             13
# departure call? (original unknown locomotion/ possibly departure call)       4
# departure call? (original unknown locomotion/possibly pre flight call)       2
# departure? (original recruitment)                                            2
# distance all?(original loud call)                                            1
# distance call                                                              399
# distance call (original loud call)                                           6
# distance call?                                                               2
# distance call? (original loud call)                                         61
# distance call? (original loud call)loud call                                 1
# distance call? (original recruitment)                                        2
# distance call?(original loud call)                                           1
# distanceCall                                                                27
# greeting call                                                               11
# hiss                                                                         9
# loud call                                                                    7
# loud call/departure call?                                                    6
# recruitment                                                                 56
# recruitment call                                                          3277
# recruitment call?                                                           33
# recruitment/contact call?                                                   51
# regular contact call                                                         5
# regular contact call??                                                       4
# regular departure call                                                     136
# regular recruitment call??                                                 127
# rolling call (original contact call, displacing)                             1
# transformation call                                                          1
# transition call                                                              2
# triumph call                                                               338
# triumph call (answer)                                                        3
# triumph call (cackling)                                                     23
# triumph call (rolling call)                                                 69
# triumph call?                                                               16
# unknown                                                                     33
# unknown (after being displaced)                                             30
# unknown (greeting context)                                                  45
# unknown (loud call)                                                          1
# unknown (original distance call)                                             3
# unknown (original loud call)                                                29
# unknown (original recruitment)                                               4
# unknown (two other geese flying over)                                        1
# unknown(original recruitment)                                                2
# unknown(original snezing)                                                    5
# Name: Clip ID, dtype: int64

# %%
call_types = [
    "unknown",
    "distance",
    "contact",
    "departure",
    "recruitment",
    "triumph",
    "alarm",
    "hiss",
    "rolling",
    "loud", 
    "greeting"
]

# %%
# dicard rows containing more than one call type label
mask = master_df['Call Type'].apply(
    lambda x: len([call_type for call_type in call_types if call_type in x.split("(")[0]]) == 1
)
master_df = master_df[mask]
# change to single word
master_df['Call Type'] = master_df['Call Type'].apply(lambda x: next((call_type for call_type in call_types if call_type in x.split("(")[0]), x))

# %%
master_df.groupby('Call Type')['Clip ID'].count()
# Out:
# Call Type
# alarm           102
# contact        1707
# departure      1012
# distance        500
# greeting         11
# hiss              9
# loud              7
# recruitment    3493
# rolling           1
# triumph         452
# unknown         153
# Name: Clip ID, dtype: int64

# %% [markdown]
# Check Goose IDs for consistency

# %%
sorted(master_df['Goose ID'].unique())
# Out:
# ['Allegra',
#  'Amelie',
#  'Anthony',
#  'Babaco',
#  'Bacardi',
#  'Baldrian',
#  'Ballantine',
#  'Batate',
#  'Baycox',
#  'Bayou',
#  'Beaker Parker',
#  'BeakerParker',
#  'Belmont',
#  'Bernard',
#  'Besenstiel',
#  'Bianca',
#  'Birne',
#  'Blossom',
#  'Bolzano',
#  'Bon Jovi',
#  'Bon Jovi_other goose',
#  'Boris',
#  'Bregenz',
#  'Brooklyn',
#  'Bruce Springsteen',
#  'Buche',
#  'Bumblebee',
#  'Burglar',
#  'Da Vinci',
#  'Dagobert',
#  'Demant',
#  'Die Lisa',
#  'Diega',
#  'Dimitri',
#  'Disney',
#  'Dorothea',
#  'Dunja',
#  'Edes',
#  'EinStein',
#  'Eisbecher',
#  'Eisbrecher',
#  'Emu',
#  'Erdbeere',
#  'Ericsson',
#  'Floki',
#  'Fortuna',
#  'Fritz',
#  'Frodo',
#  'Ginny',
#  'Giovanni',
#  'Hedwig',
#  'Hera',
#  'Idgie',
#  'Ingeborg',
#  'Jafar',
#  'Janosch',
#  'Jewel',
#  'Joe',
#  'Joshua',
#  'Julian',
#  'Jurek',
#  'Karolina',
#  'Kendo',
#  'Kiki',
#  'Kleine Hexe',
#  'Koarl',
#  'Kokosnuss',
#  'Kolibri',
#  'Kruemmel',
#  'Krümmel',
#  'Lagertha',
#  'Lando',
#  'Laszlo',
#  'Lauri',
#  'Lausbursch',
#  'Laxi',
#  'Lazlo',
#  'Leberbluemchen',
#  'Leia',
#  'Lindy Hop',
#  'LindyHop',
#  'Longshanks',
#  'Lukka',
#  'Lumpy',
#  'Luna',
#  'Lupin',
#  'Luzifer',
#  'Macchia',
#  'Murphy',
#  'Natalie',
#  'Obelix',
#  'Oberlix',
#  'Odessa',
#  'Olaf',
#  'Olga',
#  'Ornella',
#  'Otmar',
#  'Pasha',
#  'Paso',
#  'Pistazie',
#  'Pudding',
#  'Rili',
#  'Rocket',
#  'Romy',
#  'Severin',
#  'Sherlock',
#  'Smoky',
#  'Taiga',
#  'Trevor',
#  'Triton',
#  'Tsitika',
#  'Tumnus',
#  'unknown']

# %%
master_df['Goose ID'] = master_df['Goose ID'].replace("Krümmel", "Kruemmel")
master_df['Goose ID'] = master_df['Goose ID'].replace("Obelix", "Oberlix")
master_df['Goose ID'] = master_df['Goose ID'].replace("Eisbecher", "Eisbrecher")
master_df = master_df.loc[master_df["Goose ID"] != 'Bon Jovi_other goose']

# %%
# remove whitespace from Goose IDs
master_df["Goose ID"] = master_df["Goose ID"].str.replace(" ", "", regex=False)

# %%
sorted(master_df['Goose ID'].unique())
# Out:
# ['Allegra',
#  'Amelie',
#  'Anthony',
#  'Babaco',
#  'Bacardi',
#  'Baldrian',
#  'Ballantine',
#  'Batate',
#  'Baycox',
#  'Bayou',
#  'BeakerParker',
#  'Belmont',
#  'Bernard',
#  'Besenstiel',
#  'Bianca',
#  'Birne',
#  'Blossom',
#  'Bolzano',
#  'BonJovi',
#  'Boris',
#  'Bregenz',
#  'Brooklyn',
#  'BruceSpringsteen',
#  'Buche',
#  'Bumblebee',
#  'Burglar',
#  'DaVinci',
#  'Dagobert',
#  'Demant',
#  'DieLisa',
#  'Diega',
#  'Dimitri',
#  'Disney',
#  'Dorothea',
#  'Dunja',
#  'Edes',
#  'EinStein',
#  'Eisbrecher',
#  'Emu',
#  'Erdbeere',
#  'Ericsson',
#  'Floki',
#  'Fortuna',
#  'Fritz',
#  'Frodo',
#  'Ginny',
#  'Giovanni',
#  'Hedwig',
#  'Hera',
#  'Idgie',
#  'Ingeborg',
#  'Jafar',
#  'Janosch',
#  'Jewel',
#  'Joe',
#  'Joshua',
#  'Julian',
#  'Jurek',
#  'Karolina',
#  'Kendo',
#  'Kiki',
#  'KleineHexe',
#  'Koarl',
#  'Kokosnuss',
#  'Kolibri',
#  'Kruemmel',
#  'Lagertha',
#  'Lando',
#  'Laszlo',
#  'Lauri',
#  'Lausbursch',
#  'Laxi',
#  'Lazlo',
#  'Leberbluemchen',
#  'Leia',
#  'LindyHop',
#  'Longshanks',
#  'Lukka',
#  'Lumpy',
#  'Luna',
#  'Lupin',
#  'Luzifer',
#  'Macchia',
#  'Murphy',
#  'Natalie',
#  'Oberlix',
#  'Odessa',
#  'Olaf',
#  'Olga',
#  'Ornella',
#  'Otmar',
#  'Pasha',
#  'Paso',
#  'Pistazie',
#  'Pudding',
#  'Rili',
#  'Rocket',
#  'Romy',
#  'Severin',
#  'Sherlock',
#  'Smoky',
#  'Taiga',
#  'Trevor',
#  'Triton',
#  'Tsitika',
#  'Tumnus',
#  'unknown']

# %% [markdown]
# Noise reduce tracks (if not already done and saved) and export clips from noise reduced tracks.

# %%
master_df['same_track'] = master_df['Track ID'].eq(master_df['Track ID'].shift())

# %%
def compute_snr(signal):
    _, _, snr, _, _, _ = spectral_snr(librosa.amplitude_to_db(np.abs(librosa.stft(signal, n_fft = 512, hop_length=(512//8))), ref=np.max))
    return snr

# %%
snrs = []
track_lengths = []
clip_lengths = []
processed_clips = []

# %%
# Create call objects
not_found_count = 0
for index, row in master_df.iterrows():
    track_id = row["Track ID"]
    if row["Clip ID"] in processed_clips:
        continue
    if not row['same_track']:
        if Path(DATAPATH+"/noise_reduced/"+track_id+"_noise_reduced.wav").is_file():
            track_data, sr = librosa.load(DATAPATH+"/noise_reduced/"+track_id+"_noise_reduced.wav", sr=None)
        elif Path([track_path for track_path in track_paths if track_id in track_path][0]).is_file():
            track_data, sr = librosa.load([track_path for track_path in track_paths if track_id in track_path][0], sr=None)
            track_data = nr.reduce_noise(y=track_data, sr=sr, stationary=False, prop_decrease=1, time_constant_s=1, freq_mask_smooth_hz=500, n_fft=512)
            wavfile.write(DATAPATH+"/noise_reduced/"+track_id+"_noise_reduced.wav", sr, track_data)
        else:
            print("unable to load track "+track_id)
            continue
        snrs.append(compute_snr(track_data))
        track_lengths.append(len(track_data)/sr)
    if len(track_data) > 0 and len(track_data[int(row["Begin Time (s)"]*sr):int(row["End Time (s)"]*sr)]) > 0:
        if not Path(OUTPATH+f"/{track_id}_{row['Clip ID']}_{row['Goose ID']}_{row['Call Type']}.wav").is_file():
            wavfile.write(OUTPATH+f"/{track_id}_{row['Clip ID']}_{row['Goose ID']}_{row['Call Type']}.wav", sr, track_data[int(row["Begin Time (s)"]*sr):int(row["End Time (s)"]*sr)])
        processed_clips.append(row["Clip ID"])
        clip_lengths.append(len(track_data[int(row["Begin Time (s)"]*sr):int(row["End Time (s)"]*sr)])/sr)
    else:
        not_found_count += 1
print(not_found_count)
# Out:
# 19

# %% [markdown]
# Inspect track lengths, goose IDs and snrs

# %%
plt.scatter(np.log(track_lengths), snrs)
plt.xlabel("track length [log(s)]")
plt.ylabel("Spectral SNR")
# Out:
# Text(0, 0.5, 'Spectral SNR')

# %%
plt.hist(np.log(clip_lengths))
plt.xlabel("clip length [log(s)]")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
# only plot occurences above count of one
counts = master_df["Goose ID"].value_counts()
filtered_df = master_df[master_df["Goose ID"].isin(counts[counts > 3].index)]

f, ax = plt.subplots(figsize=(30, 5))
sns.despine(f)

sns.histplot(
    filtered_df,
    x="Goose ID",
    multiple="stack",
    hue="Call Type",
    palette="viridis",
    edgecolor="1",
    linewidth=.5,
    shrink=.7,
)
plt.xticks(rotation=-45, ha='left')
plt.xlim(left=-0.5, right=len(filtered_df["Goose ID"].unique()))
plt.plot()
# Out:
# []
